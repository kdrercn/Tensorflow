# %%
import pandas as pd

# %%
dataFrame = pd.read_excel("nba1.xlsx")

# %%
dataFrame.head()
# Out:
#    Rk  G 2006 Playoffs Series   Tm Unnamed: 5  Opp  G# Unnamed: 8  GS  ...  \
# 0   1  1    2006-04-22    EC1  CLE   0.310415  WAS   1    W (+11)   1  ...
# 1   2  2    2006-04-25    EC1  CLE        NaN  WAS   2     L (-5)   1  ...
# 2   3  3    2006-04-28    EC1  CLE          @  WAS   3     W (+1)   1  ...
# 3   4  4    2006-04-30    EC1  CLE          @  WAS   4    L (-10)   1  ...
# 4   5  5    2006-05-03    EC1  CLE        NaN  WAS   5     W (+1)   1  ...
#
#   DRB  TRB  AST  STL  BLK  TOV  PF  PTS  GmSc  +/-
# 0   8   11   11    0    0    4   3   32  23.3   11
# 1   7    9    2    2    3   10   5   26   6.7   -2
# 2   4    5    3    2    0    4   3   41  27.4    1
# 3   5    6    5    0    0    7   5   38  23.0  -16
# 4   2    7    6    2    0    4   5   45  38.4   -4
#
# [5 rows x 31 columns]

# %%
import seaborn as sbn
import matplotlib.pyplot as plt

# %%
from sklearn.model_selection import train_test_split

# %%
# y = wx + b
# y -> label
y = dataFrame["PTS"].values

# x -> feature (özellik)
x = dataFrame[["3P%","FG%","FT%"]].values

x_train, x_test, y_train, y_test = train_test_split(x,y,test_size=0.33,random_state=15)

# %%
x_train.shape
# Out:
# (174, 3)

# %%
x_test.shape
# Out:
# (86, 3)

# %%
y_train.shape
# Out:
# (174,)

# %%
y_test.shape
# Out:
# (86,)

# %%
from sklearn.preprocessing import MinMaxScaler

# %%
scaler = MinMaxScaler()

# %%
scaler.fit(x_train)
# Out:
# MinMaxScaler()

# %%
x_train = scaler.transform(x_train)
x_test = scaler.transform(x_test)

# %%
x_train
# Out:
# array([[0.2       , 0.56462585, 0.79125   ],
#        [0.667     , 0.82040816, 0.58375   ],
#        [0.333     , 0.5292517 , 0.46375   ],
#        [0.25      , 0.49387755, 0.5       ],
#        [0.25      , 0.5292517 , 0.7225    ],
#        [0.5       , 0.44489796, 1.        ],
#        [0.5       , 0.64897959, 0.16625   ],
#        [0.2       , 0.46122449, 0.46375   ],
#        [0.25      , 0.67482993, 0.615     ],
#        [0.667     , 0.62585034, 0.58375   ],
#        [0.5       , 0.72380952, 0.375     ],
#        [0.        , 0.23809524, 0.91125   ],
#        [0.333     , 0.5292517 , 0.0625    ],
#        [0.5       , 0.70884354, 1.        ],
#        [0.417     , 0.5292517 , 0.86125   ],
#        [0.        , 0.59047619, 0.6875    ],
#        [0.        , 0.38095238, 0.84375   ],
#        [0.4       , 0.4585034 , 0.7225    ],
#        [0.4       , 0.43265306, 0.84375   ],
#        [0.375     , 0.5292517 , 0.75      ],
#        [1.        , 0.56462585, 0.75      ],
# ...

# %%
import tensorflow as tf

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense

# %%
model = Sequential()

model.add(Dense(4,activation="relu"))
model.add(Dense(4,activation="relu"))
model.add(Dense(4,activation="relu"))


model.add(Dense(1))

model.compile(optimizer = "rmsprop",loss = "mse")

# %%
model.fit(x_train,y_train,epochs=300)
# Out:
# Epoch 1/300
# 6/6 [==============================] - 0s 997us/step - loss: 807.4255
# Epoch 2/300
# 6/6 [==============================] - 0s 997us/step - loss: 807.0987
# Epoch 3/300
# 6/6 [==============================] - 0s 998us/step - loss: 806.7745
# Epoch 4/300
# 6/6 [==============================] - 0s 2ms/step - loss: 806.4537
# Epoch 5/300
# 6/6 [==============================] - 0s 997us/step - loss: 806.1293
# Epoch 6/300
# 6/6 [==============================] - 0s 1ms/step - loss: 805.8045
# Epoch 7/300
# 6/6 [==============================] - 0s 2ms/step - loss: 805.4800
# Epoch 8/300
# 6/6 [==============================] - 0s 1ms/step - loss: 805.1556
# Epoch 9/300
# 6/6 [==============================] - 0s 1ms/step - loss: 804.8270
# Epoch 10/300
# 6/6 [==============================] - 0s 1ms/step - loss: 804.5050
# Epoch 11/300
# 6/6 [==============================] - 0s 2ms/step - loss: 804.1804
# Epoch 12/300
# ...

# %%
loss = model.history.history["loss"]

# %%
sbn.lineplot(x=range(len(loss)),y=loss)
# Out:
# <AxesSubplot:>

# %%
trainLoss = model.evaluate(x_train,y_train, verbose=0)

# %%
testLoss = model.evaluate(x_test,y_test,verbose=0)

# %%
trainLoss
# Out:
# 53.895023345947266

# %%
testLoss
# Out:
# 49.71552658081055

# %%
testTahminleri = model.predict(x_test)

# %%
testTahminleri
# Out:
# array([[40.966393],
#        [25.661179],
#        [34.560818],
#        [22.118015],
#        [40.087696],
#        [33.705906],
#        [23.77686 ],
#        [20.974234],
#        [32.298042],
#        [27.580755],
#        [34.659527],
#        [26.00389 ],
#        [28.83857 ],
#        [27.81826 ],
#        [27.359089],
#        [27.439186],
#        [28.742193],
#        [21.241665],
#        [25.301416],
#        [30.104422],
#        [37.138187],
#        [34.227665],
#        [31.055277],
#        [26.942564],
#        [27.510471],
#        [21.025036],
#        [31.421574],
#        [28.023348],
#        [32.85983 ],
#        [33.913082],
#        [36.565376],
#        [29.120075],
#        [20.839884],
#        [27.999882],
#        [24.098614],
#        [28.0953  ],
#        [31.042582],
#        [29.215483],
#        [26.679024],
#        [29.394522],
#        [28.550156],
#        [33.93804 ],
#        [26.34935 ],
#        [31.14613 ],
#        [41.43825 ],
# ...

# %%
tahminDf = pd.DataFrame(y_test,columns=["Gerçek Y"])

# %%
tahminDf
# Out:
#     Gerçek Y
# 0         27
# 1         32
# 2         37
# 3         19
# 4         30
# ..       ...
# 81         8
# 82        27
# 83        35
# 84        26
# 85        29
#
# [86 rows x 1 columns]

# %%
testTahminleri = pd.Series(testTahminleri.reshape(86,))

# %%
testTahminleri
# Out:
# 0     40.966393
# 1     25.661179
# 2     34.560818
# 3     22.118015
# 4     40.087696
#         ...
# 81    20.580509
# 82    31.601179
# 83    26.300756
# 84    34.114246
# 85    30.911739
# Length: 86, dtype: float32

# %%
tahminDf = pd.concat([tahminDf,testTahminleri],axis=1)

# %%
tahminDf
# Out:
#     Gerçek Y          0
# 0         27  40.966393
# 1         32  25.661179
# 2         37  34.560818
# 3         19  22.118015
# 4         30  40.087696
# ..       ...        ...
# 81         8  20.580509
# 82        27  31.601179
# 83        35  26.300756
# 84        26  34.114246
# 85        29  30.911739
#
# [86 rows x 2 columns]

# %%
tahminDf.columns = ["Gerçek Y", "Tahmin Y"]

# %%
tahminDf
# Out:
#     Gerçek Y   Tahmin Y
# 0         27  40.966393
# 1         32  25.661179
# 2         37  34.560818
# 3         19  22.118015
# 4         30  40.087696
# ..       ...        ...
# 81         8  20.580509
# 82        27  31.601179
# 83        35  26.300756
# 84        26  34.114246
# 85        29  30.911739
#
# [86 rows x 2 columns]

# %%
sbn.scatterplot(x = "Gerçek Y", y = "Tahmin Y", data = tahminDf)
# Out:
# <AxesSubplot:xlabel='Gerçek Y', ylabel='Tahmin Y'>

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error

# %%
mean_absolute_error(tahminDf["Gerçek Y"],tahminDf["Tahmin Y"])
# Out:
# 5.677024508631507

# %%
mean_squared_error(tahminDf["Gerçek Y"],tahminDf["Tahmin Y"])
# Out:
# 47.36436846749758

# %%
dataFrame.describe()
# Out:
#                Rk           G          G#     GS          FG         FGA  \
# count  260.000000  260.000000  260.000000  260.0  260.000000  260.000000
# mean   130.500000   10.200000    3.257692    1.0   10.273077   20.723077
# std     75.199734    5.961135    1.683138    0.0    3.347108    5.245355
# min      1.000000    1.000000    1.000000    1.0    2.000000   10.000000
# 25%     65.750000    5.000000    2.000000    1.0    8.000000   17.000000
# 50%    130.500000   10.000000    3.000000    1.0   10.000000   20.000000
# 75%    195.250000   15.000000    4.000000    1.0   12.000000   24.000000
# max    260.000000   23.000000    7.000000    1.0   20.000000   38.000000
#
#               FG%          3P         3PA         3P%  ...         DRB  \
# count  260.000000  260.000000  260.000000  260.000000  ...  260.000000
# mean     0.496785    1.592308    4.750000    0.310415  ...    7.515385
# std      0.115955    1.396057    2.266722    0.223639  ...    2.860285
# ...

# %%
yeniG = [[0.2,0.3,0]]

# %%
yeniG = scaler.transform(yeniG)

# %%
model.predict(yeniG)
# Out:
# array([[16.370426]], dtype=float32)
